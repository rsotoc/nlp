# %% [markdown]
# ![agents](images/header.jpg)
# # Análisis semántico
# ### Ramón Soto C. [(rsotoc@moviquest.com)](mailto:rsotoc@moviquest.com/)
# [ver en nbviewer](http://nbviewer.ipython.org/github/rsotoc/nlp/blob/master/6.%20Modelado%20de%20temas%3A%20DLA.ipynb)

# %% [markdown]
# ![ ](images/blank.png)
# ## Definición
#
# La semántica es, de acuerdo con el [DRAE](http://dle.rae.es/?id=XVRDns5), la...
#
# > Disciplina que estudia el significado de las unidades lingüísticas y de sus combinaciones.
#
# El análisis semántico consiste en analizar el significado de un conjunto de palabras, símbolos y frases, en un contexto específico, con el fin de determinar el mensaje contenido en el texto.
#
# ![](images/nlp02e.png)
#
# En el caso del procesamiento de lenguaje natural, la etapa de análisis semántico toma el flujo de tokens provenientes del análisis léxico, posiblemente categorizadas en los pasos previos, para generar una interpretación del texto.
#
# Sin embargo, tratar de interpretar un mensaje de texto, escrito con muchas libertades, es un problema sumamente complejo aún cuando el texto se encuentre construido de forma correcta. Considérese, por ejemplo, el siguiente monólogo clásico de *Groucho Marx* (*Animal Crackers*, 1930):
#
# > *One morning I shot an elephant in my pajamas. <br>
# > How he got in my pajamas, I don't know.* ![](images/groucho.jpg)
#
# Aunque la situación es utilizada como broma, particularmente al ser forzada por Groucho Marx, la estructura es sintácticamente correcta. La interpretación "lógica" se obtiene integrando diversos elementos no disponibles en el texto, particularmente los siguientes: 1) Un elefante no cabe en unas piyamas humanas, y 2) El autor está bromeando.
#
# El alcance del análisis semántico automatizado de lenguajes naturales se limita a tareas específicas, destacándose las siguientes:
#
# * Sistemas de traducción
# * Sistemas preguntadores/respondedores
# * Sistemas resumidores
# * Sistemas de correción ortográfica
# * Identificación temática
# * Análisis de sentimientos
#
# Siendo las dos últimas las más activas actualmente.

# %% [markdown]
# ## Modelado de tópicos
#
# El modelado de tópicos es una tarea cuyo objetivo es identificar tópicos a partir de una colección de documentos (un corpus). Usualmente, toda la información que se tiene de un corpus es la distribución de palabras utilizadas y, posiblemente, el número de clases/tópicos que se quieren identificar. Para realizar la identificación de los tópicos en una colección de documentos se utilizan técnicas especializadas de aprendizaje no supervisado (*clustering*). Los modelos resultantes suelen definirse mediante funciones de distribución de probabilidades sobre el conjunto de palabras utilizadas en el corpus.
#
# Existen diferentes aproximaciones para realizar el modelado de tópicos, siendo las más sobresalientes las técnicas **PLSI** (*probabilistic latent semantic indexing* - indexado probabilístico de semántica latente), **NNMF** (*non-negative matrix factorization* -  factorización de matrices no negativas) y **LDA** (*Latent Dirichlet Allocation* - Asignación latente de Dirichlet).
#
#
# ### Factorización de matrices no negativas (NNMF/NMF)
#
# Una forma muy común de representar una colección de documentos es mediante una **matriz documentos-términos**. En una matriz documentos-términos los renglones representan documentos y las columnas corresponden a los términos. Las celdas suelen contener medidas de importancia de cada término en un documento dado, por ejemplo, mediante valores de tf-idf. Una dificultad al utilizar estas matrices para representar la colección de documentos es la cantidad de atributos utilizados.
#
# El objetivo de la técnica NMF es obtener una factorización de la matriz original $\mathbf{V}$ en dos matrices de menor rango $\mathbf{W}$ y $\mathbf{H}$. Dado que el problema no tiene solución exacta para el caso general, lo usual es obtener una solución aproximada:
#
# ![](images/nmf.png)
#
# generar un conjunto reducido de nuevos rasgos, a partir de la matriz original de documentos-términos.
#
#
#
# Just as its name suggests, matrix factorization is to, obviously, factorize a matrix, i.e. to find out two (or more) matrices such that when you multiply them you will get back the original matrix.
#
# NMF takes as an input a term-document matrix and generates a set of topics that represent weighted sets of co-occurring terms. The discovered topics form a basis that provides an efficient representation of the original documents.
#
#
#
# Another way to think about it is that NMF breaks your original data features (let's call it V) into the product of two lower ranked matrices (let's call it W and H). NMF uses an iterative approach to modify the initial values of W and H so that the product approaches V. When the approximation error converges or the user-defined number of iterations is reached, NMF terminates.

# %%
from IPython.display import display
import pandas as pd
import numpy as np 
pd.options.display.max_colwidth = 150 

import nltk
import re

# %%
import json

file = 'Data Sets/Comics/lexicon_comics.json'
with open(file) as comics_file:
    dict_comics = json.load(comics_file)

comicsDf = pd.DataFrame.from_dict(dict_comics).reindex_axis(
    ['name',"description", "main_words", "new_description"], axis=1)

display(comicsDf.head(5))
# Out:
#                    name  \
# 0           'Mazing Man
# 1  711 (Quality Comics)
# 2         Abigail Brand
# 3              Abin Sur
# 4         Abner Jenkins
#
#                                                                                                                                              description  \
# 0  mazing man is the title character of a comic book series created by bob rozakis and stephen destefano and published by dc comics the series ran fo...
# 1  is a fictional superhero from the golden age of comics he was created by george brenner and published by quality comics first appeared in police c...
# 2  special agent special agent abigail brand is a fictional character appearing in american comic book s published by marvel comics publication histo...
# 3  abin sur is a fictional character and a superhero from the dc comics dc universe he was a member of the green lantern corps and is best known as t...
# 4  abner ronald jenkins formerly known as the beetle comics beetle mach iv mach v mach vii and currently known as mach x and is a fictional character...
#
#                                                                                                                                               main_words  \
# 0  [man, title, character, comic, book, series, created, bob, rozakis, stephen, published, dc, comics, series, ran, twelve, issues, additional, speci...
# 1  [fictional, superhero, golden, age, comics, created, george, published, quality, comics, first, appeared, police, comics, august, lasted, january,...
# 2  [special, agent, special, agent, abigail, brand, fictional, character, appearing, american, comic, book, published, marvel, comics, publication, h...
# 3  [abin, sur, fictional, character, superhero, dc, comics, dc, universe, member, green, lantern, corps, best, known, predecessor, green, lantern, ha...
# 4  [abner, ronald, jenkins, formerly, known, beetle, comics, beetle, mach, mach, mach, vii, currently, known, mach, x, fictional, character, appearin...
#
#                                                                                                                                          new_description
# 0  mazing_man man title_character comic_book series_created bob_rozakis stephen published dc_comics series ran twelve_issues additional_special_issue...
# 1  711_quality_comics fictional superhero golden_age comics_created george_published quality_comics first_appeared police_comics_august lasted januar...
# 2  abigail_brand special agent special agent abigail_brand fictional character_appearing american_comic_book published marvel_comics publication hist...
# 3  abin_sur abin sur fictional character_superhero dc_comics dc_universe member green_lantern corps best_known predecessor green_lantern hal_jordan a...
# 4  abner_jenkins abner ronald jenkins formerly_known beetle_comics beetle mach mach mach_vii currently known mach x_fictional character_appearing ame...

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(comicsDf.new_description)
X_array = X.toarray()
X_vocab = np.array(vectorizer.get_feature_names())

# %%
#print(X.shape, "\n", X_array[2, 0:100], "\n", X_vocab[0:100])
for i, x in zip(range(len(X_vocab)), X_array[2]):
    if x > 5:
        print(i, x, X_vocab[i])
# Out:
# 57 6 abigail
# 59 14 abigail_brand
# 4444 7 appears
# 5633 8 astonishing_x_men
# 7722 10 beast
# 10584 46 brand
# 10651 12 breakworld
# 23495 10 earth
# 50426 6 mccoy
# 53323 6 mutant
# 58203 7 ord
# 66824 6 revealed
# 78092 25 sword
# 89478 11 x_men

# %%
from sklearn import decomposition

num_topics = 6
num_top_words = 100
clf = decomposition.NMF(n_components=num_topics, random_state=1)
doctopic = clf.fit_transform(X)

# %%
topic_words = []
for topic in clf.components_:
    word_idx = np.argsort(topic)[::-1][0:num_top_words]
    topic_words.append([X_vocab[i] for i in word_idx])

# %%
for row in topic_words:
    print(row, "\n")
# Out:
# ['batman', 'nightwing', 'robin', 'damian', 'batgirl', 'dick', 'joker', 'dick_grayson', 'character', 'anarky', 'bruce', 'dc_comics', 'catwoman', 'jason', 'series', 'barbara_gordon', 'appears', 'gotham', 'justice_league', 'also', 'father', 'terry', 'bruce_wayne', 'new', 'death', 'selina', 'role', 'grayson', 'batman_robin', 'oracle', 'todd', 'batwoman', 'voiced', 'following', 'teen_titans', 'one', 'however', 'son', 'gotham_city', 'costume', 'version', 'time', 'two', 'later', 'story', 'red_hood', 'jason_todd', 'dc', 'revealed', 'birds', 'detective_comics', 'although', 'order', 'end', 'identity', 'tim', 'nightwing_vol', 'damian_wayne', 'killed', 'comics', 'game', 'would', 'tim_drake', 'part', 'episode', 'made', 'harley_quinn', 'kill', 'events', 'return', 'returns', 'prey', 'barbara', 'daughter', 'battle', 'family', 'file', 'talia', 'batman_beyond', 'life', 'team', 'become', 'takes', 'red_robin', 'film', 'green_arrow', 'comic_book', 'continuity', 'left', 'thumb', 'circus', 'first', 'villain', 'issue', 'still', 'city', 'help', 'art', 'well', 'league']
#
# ['x_men', 'wolverine', 'cyclops', 'uncanny_x_men', 'rogue', 'marvel_comics', 'magneto', 'comics', 'xavier', 'apocalypse', 'mutant', 'powers', 'mutants', 'time', 'mystique', 'team', 'jean', 'vol', 'phoenix', 'sabretooth', 'also', 'gambit', 'one', 'jean_grey', 'storm', 'beast', 'iceman', 'colossus', 'scott', 'psylocke', 'x_factor', 'cable', 'body', 'phoenix_force', 'kitty', 'new_x_men', 'nightcrawler', 'however', 'emma_frost', 'later', 'emma', 'able', 'help', 'school', 'battle', 'new', 'control', 'new_mutants', 'professor_x', 'angel', 'back', 'revealed', 'frost', 'series', 'member', 'death', 'character', 'marvel', 'juggernaut', 'mind', 'power', 'x_force', 'ability', 'would', 'earth', 'kill', 'logan', 'warren', 'havok', 'two', 'use', 'hope', 'dazzler', 'using', 'relationship', 'bishop', 'future', 'part', 'fight', 'life', 'brotherhood', 'left', 'utopia', 'though', 'along', 'jubilee', 'attack', 'well', 'father', 'could', 'due', 'order', 'even', 'appears', 'shi', 'world', 'bobby', 'characters', 'killed', 'legacy']
#
# ['spider_man', 'peter', 'amazing_spider_man', 'mary_jane', 'black_cat', 'sandman', 'kaine', 'peter_parker', 'spider', 'harry', 'venom', 'flash', 'comics', 'symbiote', 'one', 'marvel_comics', 'parker', 'game', 'reilly', 'ben', 'father', 'character', 'time', 'spider_woman', 'ultimate_spider_man', 'version', 'marvel', 'scarlet_spider', 'green_goblin', 'doctor_octopus', 'life', 'also', 'however', 'later', 'costume', 'morbius', 'ben_reilly', 'carnage', 'appears', 'voiced', 'killed', 'new_york', 'video', 'jackal', 'may', 'powers', 'spider_girl', 'new', 'fight', 'spider_verse', 'vol', 'felicia', 'help', 'identity', 'spectacular_spider_man', 'clone', 'revealed', 'aunt_may', 'brock', 'watson', 'kingpin', 'characters', 'series', 'first', 'harry_osborn', 'tv_series', 'would', 'body', 'agent_venom', 'issue', 'wolverine', 'superior_spider_man', 'comic_book', 'norman_osborn', 'still', 'uncle', 'death', 'using', 'back', 'norman', 'storyline', 'tells', 'gwen_stacy', 'kill', 'eddie_brock', 'relationship', 'earth', 'created', 'takes', 'become', 'following', 'eventually', 'due', 'two', 'sand', 'like', 'original', 'end', 'web', 'return']
#
# ['green_lantern', 'sinestro', 'ring', 'corps', 'hal', 'hal_jordan', 'kyle', 'guardians', 'jordan', 'justice_league', 'parallax', 'earth', 'sinestro_corps', 'guy', 'ganthet', 'green_lanterns', 'rayner', 'power_ring', 'carol', 'universe', 'power', 'new', 'green_arrow', 'war', 'john', 'kyle_rayner', 'guy_gardner', 'dc_comics', 'battle', 'fear', 'appears', 'yellow', 'voiced', 'one', 'time', 'gardner', 'john_stewart', 'lanterns', 'planet', 'rings', 'stewart', 'kilowog', 'however', 'indigo', 'blackest_night', 'abin_sur', 'superman', 'mogo', 'green', 'vol', 'attack', 'fight', 'also', 'revealed', 'help', 'star_sapphire', 'later', 'back', 'batman', 'krona', 'life', 'role', 'two', 'lantern', 'member', 'able', 'spectre', 'carol_ferris', 'use', 'vol_green_lantern', 'dc_comicscom', 'alan_scott', 'entity', 'order', 'korugar', 'flash', 'world', 'episode', 'defeat', 'would', 'control', 'new_guardians', 'left', 'powers', 'due', 'although', 'first', 'escape', 'emerald', 'well', 'heroes', 'return', 'attacks', 'book', 'created', 'brightest_day', 'atrocitus', 'character', 'ion', 'soranik']
#
# ['superman', 'luthor', 'superboy', 'clark', 'clark_kent', 'lex_luthor', 'dc_comics', 'character', 'siegel', 'earth', 'jor_el', 'supergirl', 'lex', 'legion', 'action_comics', 'justice_league', 'also', 'krypton', 'kryptonite', 'man', 'shuster', 'smallville', 'time', 'steel', 'first', 'lois', 'bizarro', 'version', 'would', 'one', 'story', 'brainiac', 'series', 'world', 'later', 'kent', 'metropolis', 'kryptonian', 'powers', 'stories', 'adventures', 'kal_el', 'episode', 'adventure_comics', 'super_heroes', 'season', 'lois_lane', 'however', 'made', 'batman', 'comic_book', 'captain_marvel', 'years', 'name', 'created', 'krypto', 'comics', 'introduced', 'well', 'new', 'son', 'wonder_woman', 'dc', 'tv_series', 'continuity', 'clone', 'characters', 'lena', 'infinite_crisis', 'life', 'doomsday', 'revealed', 'power_girl', 'appears', 'even', 'shazam', 'shown', 'planet', 'could', 'father', 'film', 'although', 'use', 'early', 'teen_titans', 'including', 'pre_crisis', 'two', 'several', 'costume', 'file', 'part', 'identity', 'end', 'using', 'category_dc_comics', 'original', 'conner', 'kara', 'history']
#
# ['avengers', 'character', 'earth', 'time', 'captain_america', 'justice_league', 'one', 'series', 'comics', 'hulk', 'appears', 'marvel_comics', 'iron_man', 'also', 'fantastic_four', 'team', 'marvel', 'later', 'new', 'battle', 'death', 'powers', 'member', 'vol', 'version', 'voiced', 'however', 'captain_marvel', 'revealed', 'power', 'characters', 'thor', 'body', 'help', 'back', 'able', 'would', 'first', 'created', 'two', 'fight', 'dc_comics', 'issue', 'part', 'world', 'stark', 'used', 'use', 'father', 'heroes', 'well', 'armor', 'life', 'killed', 'ability', 'comic_book', 'using', 'introduced', 'group', 'episode', 'appeared', 'black_panther', 'due', 'head', 'made', 'although', 'wonder_woman', 'shield', 'storyline', 'game', 'name', 'order', 'shazam', 'left', 'along', 'several', 'tv_series', 'vision', 'take', 'hawkeye', 'story', 'return', 'became', 'written', 'following', 'flash', 'original', 'kill', 'become', 'aquaman', 'hercules', 'even', 'category_fictional', 'control', 'title', 'playable_character', 'moon_knight', 'still', 'though', 'eventually']

# %%
print(doctopic.shape)
# Out:
# (1867, 6)

# %%
doctopic = doctopic / np.sum(doctopic, axis=1, keepdims=True)
# Out:
# /Users/rsotoc/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: RuntimeWarning: invalid value encountered in true_divide
#   if __name__ == '__main__':

# %%
page_titles = np.asarray(list(comicsDf.name))

doctopic_orig = doctopic.copy()
num_groups = len(set(page_titles))
doctopic_grouped = np.zeros((num_groups, num_topics))


for i, name in enumerate(sorted(set(page_titles))):
    doctopic_grouped[i, :] = np.mean(doctopic[page_titles == name, :], axis=0)
    
doctopic = doctopic_grouped

print(doctopic)
# Out:
# [[ 0.31599468  0.          0.05157035  0.          0.12851462  0.50392035]
#  [ 0.13392905  0.          0.02166091  0.02840468  0.16993469  0.64607067]
#  [ 0.          0.38255308  0.07975503  0.0456573   0.          0.49203458]
#  ...,
#  [ 0.01535451  0.02111365  0.00742057  0.00203582  0.00461344  0.94946201]
#  [ 0.0159539   0.00909364  0.1671601   0.          0.01801538  0.78977698]
#  [ 0.02020925  0.03463927  0.02296386  0.04837711  0.50871322  0.36509729]]

# %%
nmf = pd.DataFrame(data=doctopic, index=page_titles, 
                   columns=["T1", "T2", "T3", "T4", "T5", "T6"])

# %%
display(nmf[250:300])
# Out:
#                                       T1        T2        T3        T4  \
# Captain Boomerang               0.227167  0.036766  0.062196  0.092536
# Captain Britain                 0.000000  0.198381  0.100846  0.024255
# Captain Carrot                  0.056014  0.000000  0.000000  0.067592
# Captain Comet                   0.058695  0.044396  0.000000  0.136902
# Captain Dynamo (comics)         0.055814  0.124480  0.052510  0.008488
# Captain Marvel (DC Comics)      0.009909  0.000000  0.000000  0.003247
# Captain Marvel (Khn'nr)         0.000000  0.030887  0.000000  0.000000
# Captain Marvel (Marvel Comics)  0.000000  0.000000  0.015743  0.000000
# Captain Marvel Jr.              0.000000  0.000000  0.000000  0.014005
# Captain Midlands                0.012794  0.047598  0.023887  0.000000
# Captain Midnight                0.062429  0.000000  0.013654  0.000000
# Captain Triumph                 0.088224  0.033616  0.027311  0.030344
# Captain Ultra                   0.000000  0.028409  0.045505  0.000000
# Captain Universe                0.000000  0.063173  0.517414  0.021825
# Cardiac (comics)                0.002765  0.061377  0.653696  0.030034
# Cardinal (comics)               0.000000  0.054760  0.084320  0.011237
# Caretaker (comics)              0.009783  0.067345  0.039533  0.042527
# Carol Danvers                   0.000000  0.166951  0.094573  0.000000
# Carol Ferris                    0.011507  0.004708  0.013381  0.904712
# Carrie Kelley                   0.988730  0.000000  0.000000  0.000000
# Cassandra Cain                  0.684858  0.038878  0.024779  0.010695
# Cassandra Lang                  0.010752  0.066543  0.069494  0.000000
# Catman (comics)                 0.615921  0.007359  0.025479  0.046373
# Catspaw (comics)                0.042367  0.000000  0.000000  0.025725
# Catwoman                        0.948939  0.014261  0.006180  0.030619
# Celestine (comics)              0.071979  0.044713  0.056621  0.000000
# Celsius (comics)                0.054755  0.051619  0.005688  0.082872
# Centrix                         0.053639  0.000000  0.000000  0.051760
# Cerebra                         0.012772  0.812843  0.036402  0.017406
# Cerise (comics)                 0.000000  0.320921  0.000000  0.018255
# Ch'od                           0.000000  0.925231  0.000000  0.000000
# Ch'p                            0.029084  0.000000  0.003132  0.924477
# Challenger (comics)             0.037704  0.058987  0.060916  0.000000
# Chamber (comics)                0.002036  0.694707  0.006533  0.008570
# Chance (comics)                 0.000000  0.002614  0.753850  0.000000
# Chantinelle                     0.041483  0.039332  0.021511  0.077966
# Chapel (comics)                 0.101508  0.038905  0.014931  0.000000
# Charcoal (comics)               0.036793  0.055544  0.048273  0.000000
# Charlie-27                      0.000000  0.098647  0.000000  0.152792
# Charlotte Jones (comics)        0.039657  0.800684  0.013003  0.000000
# Chas Chandler (comics)          0.066684  0.020046  0.077151  0.085111
# Chase Stein                     0.027417  0.085763  0.023837  0.000000
# Chemical King                   0.080929  0.014670  0.000000  0.047260
# Chief (comics)                  0.269436  0.045971  0.005206  0.059676
# Chlorophyll Kid                 0.000000  0.018039  0.016736  0.000000
# Chris Bradley                   0.009184  0.642089  0.026275  0.000000
# Chris KL-99                     0.057981  0.000000  0.007591  0.078420
# Christian Walker                0.037164  0.071721  0.056114  0.054458
# Chronos (comics)                0.282437  0.029289  0.007596  0.157654
# Chunk (comics)                  0.040984  0.000000  0.000000  0.000000
#
#                                       T5        T6
# Captain Boomerang               0.058436  0.522898
# Captain Britain                 0.000000  0.676518
# Captain Carrot                  0.156617  0.719777
# Captain Comet                   0.221042  0.538964
# Captain Dynamo (comics)         0.147229  0.611479
# Captain Marvel (DC Comics)      0.367814  0.619030
# Captain Marvel (Khn'nr)         0.028714  0.940399
# Captain Marvel (Marvel Comics)  0.094394  0.889863
# Captain Marvel Jr.              0.162557  0.823438
# Captain Midlands                0.015295  0.900427
# Captain Midnight                0.180120  0.743797
# Captain Triumph                 0.128773  0.691732
# Captain Ultra                   0.000000  0.926087
# Captain Universe                0.000000  0.397588
# Cardiac (comics)                0.000000  0.252127
# Cardinal (comics)               0.000000  0.849683
# Caretaker (comics)              0.002635  0.838178
# Carol Danvers                   0.000000  0.738475
# Carol Ferris                    0.007655  0.058037
# Carrie Kelley                   0.011270  0.000000
# Cassandra Cain                  0.000000  0.240790
# Cassandra Lang                  0.000000  0.853211
# Catman (comics)                 0.056020  0.248848
# Catspaw (comics)                0.420203  0.511705
# Catwoman                        0.000000  0.000000
# Celestine (comics)              0.117301  0.709386
# Celsius (comics)                0.057345  0.747721
# Centrix                         0.099309  0.795292
# Cerebra                         0.025870  0.094707
# Cerise (comics)                 0.014134  0.646689
# Ch'od                           0.001735  0.073034
# Ch'p                            0.017217  0.026089
# Challenger (comics)             0.091526  0.750868
# Chamber (comics)                0.022620  0.265535
# Chance (comics)                 0.000000  0.243535
# Chantinelle                     0.105704  0.714005
# Chapel (comics)                 0.047979  0.796677
# Charcoal (comics)               0.086658  0.772732
# Charlie-27                      0.000000  0.748560
# Charlotte Jones (comics)        0.000000  0.146656
# Chas Chandler (comics)          0.069679  0.681329
# Chase Stein                     0.000000  0.862983
# Chemical King                   0.479662  0.377479
# Chief (comics)                  0.084979  0.534732
# Chlorophyll Kid                 0.437376  0.527849
# Chris Bradley                   0.002156  0.320296
# Chris KL-99                     0.176870  0.679138
# Christian Walker                0.073447  0.707096
# Chronos (comics)                0.088361  0.434662
# Chunk (comics)                  0.049442  0.909574

# %% [markdown]
# ## Asignación latente de Dirichlet

# %%
import re

texto = re.sub("[^\w*]", " ", "Este es un ejemplo $123 @xy45%")
texto = re.sub("[\d]", " ", texto)
print (texto)
# Out:
# Este es un ejemplo       xy

# %%
new_main_words = []
for row in comicsDf.new_description:
    new_main_words.extend(row.split())
common_new_main_words = nltk.FreqDist(new_main_words)
uselessWords = common_new_main_words.hapaxes()
print("Cantidad de palabras sin utilidad: ", len(uselessWords))

# %%
for i, row in zip(range(len(comicsDf)), comicsDf.new_description):
    for w in uselessWords:
        row = re.sub(" " + w[0], " " + "_".join(w[0].split()), row)
    comicsDf.loc[i, "new_description"] = n.lower() + s


print("Cantidad de tokens en el corpus: ", len(common_new_main_words.most_common()))

# %%
print(uselessWords[1100:1200])
